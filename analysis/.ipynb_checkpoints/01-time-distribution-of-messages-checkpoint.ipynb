# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data_p = '../../data/'

# %%
df = pd.read_csv(data_p + 'clean_messages.csv')
df = df.dropna()
df.head()
# Out:
#                       content sender_name   timestamp_ms     type  \
# 3                No it's okay   å¾å­è±ª  1459881221299  Generic
# 6   Kinda tied up right now..   å¾å­è±ª  1459881184462  Generic
# 8                  ä½ ï¼ó°   å¾å­è±ª  1459881035831  Generic
# 11   I am sorry plz remind me   å¾å­è±ª  1459880971259  Generic
# 12               Do I know u?   å¾å­è±ª  1459880962687  Generic
#
#                   date_time  year  month  day  hour  weekday
# 3   2016-04-05 11:33:41.299  2016      4    5    11        1
# 6   2016-04-05 11:33:04.462  2016      4    5    11        1
# 8   2016-04-05 11:30:35.831  2016      4    5    11        1
# 11  2016-04-05 11:29:31.259  2016      4    5    11        1
# 12  2016-04-05 11:29:22.687  2016      4    5    11        1

# %%
for col in ['year', 'month', 'day', 'hour', 'weekday']:
    sns.countplot(df[col])
    plt.title(col)
    plt.show()

# %%
df.groupby('year').count()
# Out:
#       content  sender_name  timestamp_ms  type  date_time  month   day  hour  \
# year
# 2014      534          534           534   534        534    534   534   534
# 2015     1849         1849          1849  1849       1849   1849  1849  1849
# 2016     5178         5178          5178  5178       5178   5178  5178  5178
# 2017     6876         6876          6876  6876       6876   6876  6876  6876
# 2018     7656         7656          7656  7656       7656   7656  7656  7656
#
#       weekday
# year
# 2014      534
# 2015     1849
# 2016     5178
# 2017     6876
# 2018     7656

# %%
from textblob import TextBlob

df['polarity'] = [TextBlob(s).sentiment.polarity for s in df['content']]
df['subjectivity'] = [TextBlob(s).sentiment.subjectivity for s in df['content']]
df['word_list'] = [TextBlob(s).words.lemmatize() for s in df['content']]
print(list(df))
df.head()
# Out:
# ['content', 'sender_name', 'timestamp_ms', 'type', 'date_time', 'year', 'month', 'day', 'hour', 'weekday', 'polarity', 'subjectivity', 'word_list']
#                       content sender_name   timestamp_ms     type  \
# 3                No it's okay   å¾å­è±ª  1459881221299  Generic
# 6   Kinda tied up right now..   å¾å­è±ª  1459881184462  Generic
# 8                  ä½ ï¼ó°   å¾å­è±ª  1459881035831  Generic
# 11   I am sorry plz remind me   å¾å­è±ª  1459880971259  Generic
# 12               Do I know u?   å¾å­è±ª  1459880962687  Generic
#
#                   date_time  year  month  day  hour  weekday  polarity  \
# 3   2016-04-05 11:33:41.299  2016      4    5    11        1  0.500000
# 6   2016-04-05 11:33:04.462  2016      4    5    11        1  0.285714
# 8   2016-04-05 11:30:35.831  2016      4    5    11        1  0.000000
# 11  2016-04-05 11:29:31.259  2016      4    5    11        1 -0.500000
# 12  2016-04-05 11:29:22.687  2016      4    5    11        1  0.000000
#
#     subjectivity                        word_list
# 3       0.500000               [No, it, 's, okay]
# 6       0.535714    [Kinda, tied, up, right, now]
# 8       0.000000                    [ä½, ï¼ó°]
# 11      1.000000  [I, am, sorry, plz, remind, me]
# 12      0.000000                 [Do, I, know, u]

# %%
sns.distplot(df['polarity'])
# Out:
# /Users/zihaoxu/ENTER/lib/python3.6/site-packages/scipy/stats/stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# 13521  1522619550274  Generic  2018-04-01 14:52:30.274  2018      4    1
# 14612  1479702807191  Generic  2016-11-20 20:33:27.191  2016     11   20
# 14852  1540879328163  Generic  2018-10-29 23:02:08.163  2018     10   29
# 15363  1427865725470  Generic  2015-03-31 22:22:05.470  2015      3   31
# 16955  1540698654508  Generic  2018-10-27 20:50:54.508  2018     10   27
# 18644  1487316698678  Generic  2017-02-16 23:31:38.678  2017      2   16
# 19793  1528639631484  Generic  2018-06-10 07:07:11.484  2018      6   10
# 20433  1517993616707  Generic  2018-02-07 00:53:36.707  2018      2    7
# 21514  1441764421875  Generic  2015-09-08 19:07:01.875  2015      9    8
# 21516  1441763960026  Generic  2015-09-08 18:59:20.026  2015      9    8
#
#        hour  weekday  polarity  subjectivity  \
# 118      12        0 -1.000000           1.0
# 415      22        2 -1.000000           1.0
# 858      23        1 -1.000000           1.0
# 1337     18        1 -0.976562           1.0
# 3554     19        2 -1.000000           1.0
# 5687     20        0 -1.000000           1.0
# 6493     19        1 -1.000000           1.0
# 6504     22        0 -1.000000           1.0
# 8350      9        6 -0.937500           1.0
# 8363      8        6 -1.000000           1.0
# 10209    19        5 -1.000000           1.0
# 10629    22        6 -1.000000           1.0
# 10674    15        2 -1.000000           1.0
# 11067    14        4 -1.000000           1.0
# 11278    13        3 -0.937500           1.0
# 13521    14        6 -1.000000           1.0
# 14612    20        6 -1.000000           1.0
# 14852    23        0 -1.000000           1.0
# 15363    22        1 -1.000000           1.0
# 16955    20        5 -1.000000           1.0
# 18644    23        3 -1.000000           1.0
# 19793     7        6 -1.000000           1.0
# 20433     0        2 -1.000000           1.0
# 21514    19        1 -1.000000           1.0
# 21516    18        1 -1.000000           1.0
#
#                                                word_list
# 118                                  [I, feel, terrible]
# 415                   [Also, Matt, 's, evil, mind, game]
# 858                                    [that, 's, awful]
# 1337   [Hey, man, I, got, caught, up, with, work, and...
# 3554                                  [Sounds, horrific]
# 5687                                                  []
# 6493                                [it, 's, so, insane]
# 6504   [but, yeah, my, pun, are, terrible, so, sugges...
# 8350   [Kinda, because, some, phrase, doe, n't, struc...
# 8363                                 [Terrible, grammar]
# 10209  [I, 'm, not, to, terrible, I, just, do, n't, h...
# 10629                    [i, forgot, to, pick, mine, up]
# 10674                                 [This, is, insane]
# 11067                                                 []
# 11278                                         [goodluck]
# 13521                                      [worst, case]
# 14612               [De, Pace, wo, n't, be, that, cruel]
# 14852                                            [Sorry]
# 15363             [Honestly, I, am, a, terrible, singer]
# 16955  [i, do, n't, think, it, helped, since, it, wa,...
# 18644                         [I, might, be, the, worst]
# 19793                                                 []
# 20433  [Wait, do, they, have, to, start, at, 6, I, ha...
# 21514  [I, can, help, with, that, with, my, insanely,...
# 21516  [I, 'll, distract, her, with, my, insane, jugg...
